# %%
t=()

# %%
type(t)
# Out:
# tuple

# %%
t1=(1,2,3,14.5,'samad')

# %%
t1[::-1]
# Out:
# ('samad', 14.5, 3, 2, 1)

# %%
t1.count(1)
# Out:
# 1

# %%
t1.index('samad')
# Out:
# 4

# %%
#index returns first occurence

# %%
#tuples are immutable

# %%
#lists are mutable

# %%
for i in t1:
    print(i)
# Out:
# 1
# 2
# 3
# 14.5
# samad

# %%
for i in t1:
    print(type(i),i)
# Out:
# <class 'int'> 1
# <class 'int'> 2
# <class 'int'> 3
# <class 'float'> 14.5
# <class 'str'> samad

# %%
t1*3
# Out:
# (1, 2, 3, 14.5, 'samad', 1, 2, 3, 14.5, 'samad', 1, 2, 3, 14.5, 'samad')

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
len(t1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 len(t1)
#
# NameError: name 't1' is not defined

# %% [markdown]
# # Set

# %%
s={}
type(s)
# Out:
# dict

# %%
s1={1,2,3,4}

# %%
type(s1)
# Out:
# set

# %%
s2={1,1,1,2,2,3}

# %%
s2
# Out:
# {1, 2, 3}

# %%
list(s2)
# Out:
# [1, 2, 3]

# %%
s4={1,2,3,4,[5,6,7,8]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s4={1,2,3,4,[5,6,7,8]}
#
# TypeError: unhashable type: 'list'

# %%
s4={1,2,3,4,(5,6,7,8)}

# %%
#set is allowing to store tuples but not list as tuples are immutable

# %%
s5={'sum','Sum'}

# %%
s5
# Out:
# {'Sum', 'sum'}

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s1[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
s1.add(5)

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
len(s1)
# Out:
# 5

# %%
s1.pop()
# Out:
# 1

# %%
s1
# Out:
# {2, 3, 4, 5}

# %%
s1.pop()
# Out:
# 2

# %%
#pop removes arbitary element

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %% [markdown]
# # Dictionary

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={"name":"samad","email":"abc@gmail","number":1234}

# %%
d
# Out:
# {'name': 'samad', 'email': 'abc@gmail', 'number': 1234}

# %%
d2={'name':'sudh','name':'abc'}

# %%
d2
# Out:
# {'name': 'abc'}

# %%
d3={234:'sam'}

# %%
d3
# Out:
# {234: 'sam'}

# %%
#keys cannot be spl case characters , list,set,dictionary

# %%
d4={[1,2,3]:123}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 d4={[1,2,3]:123}
#
# TypeError: unhashable type: 'list'

# %%
d12={"course":['dsa','java']}

# %%
#value can be list tuple set dictionary

# %%
d12['time']=(4,5)

# %%
d12
# Out:
# {'course': ['dsa', 'java'], 'time': (4, 5)}

# %%
d12['course']
# Out:
# ['dsa', 'java']

# %%
del d12['time']

# %%
d12
# Out:
# {'course': ['dsa', 'java']}

# %%
d12.clear()

# %%
d12
# Out:
# {}

# %%
len(d2)
# Out:
# 1

# %%
d2.keys()
# Out:
# dict_keys(['name'])

# %%
list(d2.items())
# Out:
# [('name', 'abc')]

# %%
d23=d2.copy()

# %%
d23
# Out:
# {'name': 'abc'}

# %%
#here no impact of change of one on other this is deep copy

# %%
d24=d23

# %%
#this is shallow copy no new memory location is created

# %%
d23.pop('name')
# Out:
# 'abc'

# %%
d23
# Out:
# {}

# %%
d.fromkeys((1,2,3),('a','b','c'))
# Out:
# {1: ('a', 'b', 'c'), 2: ('a', 'b', 'c'), 3: ('a', 'b', 'c')}

# %%
d19={'key1':'value1','key2':'value2'}
d20={'key3':'value3','key4':'value4'}

# %%
(d19,d20)
# Out:
# ({'key1': 'value1', 'key2': 'value2'}, {'key3': 'value3', 'key4': 'value4'})

# %%
d19.update(d20)

# %%
d19
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
d19.get("sam")

# %%
d19.get('key3')
# Out:
# 'value3'

# %%
d19['key3']
# Out:
# 'value3'

# %% [markdown]
# Dictionary Comprehension

# %%
{i:i**2for i in range(1,11)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
