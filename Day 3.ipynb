# %% [markdown]
# # reverse a string

# %%
str1='data science masters'
str1[::-1]
# Out:
# 'sretsam ecneics atad'

# %%
reversed(str1)

# %%
" ".join(reversed(str1))
# Out:
# 's r e t s a m   e c n e i c s   a t a d'

# %%
# removing characters from end of string

# %%
stra=" pwskills "

# %%
stra.strip(" ")
# Out:
# 'pwskills'

# %%
stra.lstrip(" ")
# Out:
# 'pwskills '

# %%
stra.rstrip(" ")
# Out:
# ' pwskills'

# %%
strb='greeting to pw skills'

# %%
strb.replace('to','from')
# Out:
# 'greeting from pw skills'

# %%
#In strings we cannot replace  a character but we can replace a word

# %%
strb
# Out:
# 'greeting to pw skills'

# %%
#replace function creates a new string

# %%
"hello\tworld"
# Out:
# 'hello\tworld'

# %%
'hello\tworld'.expandtabs()
# Out:
# 'hello   world'

# %%
str1="welcome to pwskills.Welcome to dat cience masters"

# %%
str1.replace('cience','science').replace('dat','data')
# Out:
# 'welcome to pwskills.Welcome to data science masters'

# %%
str1.isupper()
# Out:
# False

# %%
str1.endswith('s')
# Out:
# True

# %%
#check if all characters in string are alpha numeric

# %%
a="abcd1234"
a.isalnum()
# Out:
# True

# %%
#count number of characters in the string

# %%
cnt=0
for i in a:
    cnt+=1
cnt
# Out:
# 8

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# a
# b
# c
# d
# 1
# 2
# 3
# 4

# %%
range(len(a))
# Out:
# range(0, 8)

# %%
for i in range(len(a)-1,-1,-1):
    print(a[i])
# Out:
# 4
# 3
# 2
# 1
# d
# c
# b
# a

# %%
name='pwskills'
vowels='AaEeIiOoUu'
for i in name:
    if i in vowels:
        print("{} is a vowel".format(i))
# Out:
# i is a vowel

# %%
#list

# %%
lst=['a','b','c','d']
lst[1::]
# Out:
# ['b', 'c', 'd']

# %%
lst[-2::]
# Out:
# ['c', 'd']

# %%
lst1=lst+[['we']]

# %%
lst1[-1][0]
# Out:
# 'we'

# %%
lst1*2
# Out:
# ['a', 'b', 'c', 'd', ['we'], 'a', 'b', 'c', 'd', ['we']]

# %%
for i in lst:
    if i=='c':
        print("yes it is present")
# Out:
# yes it is present

# %%
max(lst)
# Out:
# 'd'

# %%
lst=[1,2,3,4,5,6]

# %%
lst.append("pwskills")

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 'pwskills']

# %%
lst.append([8,9,6])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 'pwskills', [8, 9, 6]]

# %%
lst.pop()
# Out:
# [8, 9, 6]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 'pwskills']

# %%
lst.pop(0)
# Out:
# 1

# %%
lst
# Out:
# [2, 3, 4, 5, 6, 'pwskills']

# %%
lst=['q','e','f','j']
lst.reverse()

# %%
lst
# Out:
# ['j', 'f', 'e', 'q']

# %%
lst.sort()

# %%
lst
# Out:
# ['e', 'f', 'j', 'q']

# %%
lst.append([1,2])
lst
# Out:
# ['e', 'f', 'j', 'q', [1, 2]]

# %%
lst.extend([1,2])

# %%
lst
# Out:
# ['e', 'f', 'j', 'q', [1, 2], 1, 2]

# %%
#Nested List

# %%
lst1=[1,2,3]
lst2=[4,5,6]
lst3=[7,8,9]

# %%
matrix=[lst1,lst2,lst3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][2]
# Out:
# 6

# %%
matrix[2][1:]
# Out:
# [8, 9]

# %%
matrix[0:2][1]
# Out:
# [4, 5, 6]

# %%
matrix[0:3:]
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0::][0]
# Out:
# [1, 2, 3]

# %%
#list comprehension

# %%
lst=[i for i in range(20)]

# %%
[i if i%2==0 else "odd" for i in range(20)]
# Out:
# [0,
#  'odd',
#  2,
#  'odd',
#  4,
#  'odd',
#  6,
#  'odd',
#  8,
#  'odd',
#  10,
#  'odd',
#  12,
#  'odd',
#  14,
#  'odd',
#  16,
#  'odd',
#  18,
#  'odd']

# %%
sum([num for num in lst if num%2==0])
# Out:
# 90

# %%
[num**2 for num in lst]
# Out:
# [0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361]

# %%
[num for sublist in matrix for num in sublist]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
