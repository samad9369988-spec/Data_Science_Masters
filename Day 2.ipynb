# %%
False*False
# Out:
# 0

# %%
not(True)*False
# Out:
# True

# %%
(not(True))*False
# Out:
# 0

# %%
lst1=[2,3,4,5]
lst2=[2,3,4,5]
id(lst1)
# Out:
# 1786605776128

# %%
id(lst2)
# Out:
# 1786605831936

# %%
lst1 is lst2
# Out:
# False

# %%
lst2=lst1

# %%
lst1 is lst2
# Out:
# True

# %%
#== checks values inside and is checks memory address

# %%
str1="sam"
str2="sam"

# %%
str1 is str2
# Out:
# True

# %%
# string is immutable i.e we cannot change items
a=2
b=2
a is b
# Out:
# True

# %%
max_speed_of_bike=100
max_speed_of_car=200
print(f"bike is faster than car:{max_speed_of_car <= max_speed_of_bike}")
# Out:
# bike is faster than car:False

# %%
a=5
b=2
a/b
# Out:
# 2.5

# %%
a//b
# Out:
# 2

# %%
var=30
bin(var)
# Out:
# '0b11110'

# %% [markdown]
# # strings

# %%
str1="samad"
str1[0]=12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 str1="samad"
# ----> 2 str1[0]=12
#
# TypeError: 'str' object does not support item assignment

# %%
str1="pw skills data science"

# %%
#slice operation
str1[5:]
# Out:
# 'ills data science'

# %%
str1[-1]
# Out:
# 'e'

# %%
str1[::-1]
# Out:
# 'ecneics atad slliks wp'

# %%
print("hello"+"world")
# Out:
# helloworld

# %%
len(str1)
# Out:
# 22

# %%
str1.find("s")
# Out:
# 3

# %%
str1.find("a",2,12)
# Out:
# 11

# %%
str1.count('a')
# Out:
# 2

# %%
str1.split(' ')
# Out:
# ['pw', 'skills', 'data', 'science']

# %%
str1.split('s')
# Out:
# ['pw ', 'kill', ' data ', 'cience']

# %%
str1.partition('s')
# Out:
# ('pw ', 's', 'kills data science')

# %%
str1="This Is Samad"
str1.lower()
# Out:
# 'this is samad'

# %%
str1.swapcase()
# Out:
# 'tHIS iS sAMAD'

# %%
str1.title()
# Out:
# 'This Is Samad'
