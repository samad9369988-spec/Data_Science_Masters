# %%
a=10

# %%
print("hello world")
# Out:
# hello world

# %%
print(123)
# Out:
# 123

# %%
age=32
print("my age is :",age)
# Out:
# my age is : 32

# %%
print(f"my age is :{age}")
# Out:
# my age is :32

# %%
#format()
name="samad"
age=22
print("my name is {} and age is {}".format(name,age))
# Out:
# my name is samad and age is 22

# %%
name="samad"
age=22
print("my name is {name} and age is {age}".format(age=age,name=name))
# Out:
# my name is samad and age is 22

# %%
## control flow
age=int(input("enter the age : "))
if age>=15 and age!=20:
    print("you are eligible to vote")
elif age==20:
    print("you are genz")
else:
    print("not eligible")
# Out:
# enter the age : 20
# you are genz

# %%
age=int(input("enter the age"))
# Out:
# enter the age20

# %%
#loop
joining_age=60
i=1
while joining_age<65:
    print("you are old")
    joining_age+=1
# Out:
# you are old
# you are old
# you are old
# you are old
# you are old

# %%
lst=[1,2,3,4,'apple','banana']

# %%
type(lst)
# Out:
# list

# %%
#python index starts from 0
for x in lst:
    print(x,end=" ")
# Out:
# 1 2 3 4 apple banana

# %%
#nested loops
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6,2):
    print(i)
# Out:
# 1
# 3
# 5

# %%
n=7
for i in range(0,n):
    for j in range(0,i+1):
        print("*",end=" ")
    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %%
#\r means just move to the left
